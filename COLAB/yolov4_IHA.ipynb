# %% [markdown]
# # Drive Bağlantısı

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Zipten Çıkarma

# %%
# !unzip "/content/drive/MyDrive/COLAB/darknet-master.zip"   -d "/content/"
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#   inflating: /content/darknet-master/dataset/data_images/1352.txt
#   inflating: /content/darknet-master/dataset/data_images/1353.png
#   inflating: /content/darknet-master/dataset/data_images/1353.txt
#   inflating: /content/darknet-master/dataset/data_images/1354.png
#   inflating: /content/darknet-master/dataset/data_images/1354.txt
#   inflating: /content/darknet-master/dataset/data_images/1355.png
#   inflating: /content/darknet-master/dataset/data_images/1355.txt
#   inflating: /content/darknet-master/dataset/data_images/1356.png
#   inflating: /content/darknet-master/dataset/data_images/1356.txt
#   inflating: /content/darknet-master/dataset/data_images/1357.png
#   inflating: /content/darknet-master/dataset/data_images/1357.txt
#   inflating: /content/darknet-master/dataset/data_images/1358.png
#   inflating: /content/darknet-master/dataset/data_images/1358.txt
# ...

# %% [markdown]
# # MAKE
# Çalıştırma (eğer sonu -lcudann -lstdc++ ile bitiyorsa sıkıntı yoktur)

# %%
# darknet'i oluşturur, böylece darknet yürütülebilir  dosyasını nesne dedektörlerini çalıştırmak veya eğitmek için kullanabiliriz
# %cd /content/darknet-master
# !make
# Out:
# /content/darknet-master
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %% [markdown]
# #Backup Bağlantısı

# %%
# !rm /content/darknet-master/backup -r # backup u siliyoruz

# %%
# !ln -s /content/drive/"MyDrive"/yolo_weights/backup /content/darknet-master/   #Drive içine oluşturduğumuz backup u bağlıyoruz
# %pwd
# Out:
# '/content/darknet-master'

# %% [markdown]
# #Eğitim

# %%
! ./darknet detector train dataset/iha.data yolov4_iha.cfg /content/darknet-master/yolov4.conv.137 -map -dont_show
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#  total_bbox = 481135, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000005, iou_loss = 0.000000, total_loss = 0.000005
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.774682), count: 3, class_loss = 0.637655, iou_loss = 0.907099, total_loss = 1.544754
# ...

# %% [markdown]
# # Map Testi

# %%
! ./darknet detector detector map dataset/iha.data yolov4_iha.cfg /content/drive/MyDrive/yolo_weights/backup/yolov4_iha_final.weights
# Out:
# /bin/bash: ./darknet: No such file or directory
